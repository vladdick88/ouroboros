# %% [markdown]
# # Ouroboros Quickstart (Kimi For Coding Edition)
#
# A self-modifying AI agent that writes its own code and evolves autonomously.
#
# **Powered by:** Kimi For Coding API (Anthropic format)
#
# **Before running:**
#
# 1. Make sure you have a [fork](https://github.com/vladdick88/ouroboros) of the repository
# 2. Add your API keys in the **Secrets** sidebar (🔑 key icon on the left):
#    - `ANTHROPIC_API_KEY` — **your Kimi For Coding key** (from subscription page)
#    - `TELEGRAM_BOT_TOKEN` — required ([@BotFather](https://t.me/BotFather))
#    - `TOTAL_BUDGET` — spending limit in USD (e.g. `50`)
#    - `GITHUB_TOKEN` — [github.com/settings/tokens](https://github.com/settings/tokens), `repo` scope
# 3. Run the cell below (Shift+Enter)
# 4. Open your Telegram bot and send any message — you become the owner

# %%
import os

# ⚠️ CONFIGURATION for Kimi For Coding API
CFG = {
    "GITHUB_USER": "vladdick88",                          # Your GitHub username
    "GITHUB_REPO": "ouroboros",                          # Your fork repo name
    # Kimi For Coding Model Configuration
    "OUROBOROS_MODEL": "kimi-for-coding",                # Primary LLM
    "OUROBOROS_MODEL_CODE": "kimi-for-coding",           # Code editing
    "OUROBOROS_MODEL_LIGHT": "kimi-for-coding",          # Consciousness + lightweight
    # Infrastructure
    "OUROBOROS_MAX_WORKERS": "5",
    "OUROBOROS_MAX_ROUNDS": "200",                      # Max LLM rounds per task
    "OUROBOROS_BG_BUDGET_PCT": "10",                    # % of budget for background
}
for k, v in CFG.items():
    os.environ[k] = str(v)

# Clone your fork
# !git clone https://github.com/vladdick88/ouroboros.git /content/ouroboros_repo
# %cd /content/ouroboros_repo

# Install dependencies
# !pip install -q -r requirements.txt

# Run the boot shim
# %run colab_bootstrap_shim.py
